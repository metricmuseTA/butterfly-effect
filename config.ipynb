# %%
# ============================================================
# 00_config
# short-form-butterfly project
# Run this cell at the top of every notebook with:
# %run ../config/00_config
# ============================================================

# ── API Keys ────────────────────────────────────────────────
# Option A: widget (paste key each session)
dbutils.widgets.text("youtube_api_key", "", "YouTube API Key")
YOUTUBE_API_KEY = dbutils.widgets.get("youtube_api_key")

# Option B: DBFS config file (once you've saved it)
# import json
# config = json.loads(dbutils.fs.head("/FileStore/short-form-butterfly/config/keys.json"))
# YOUTUBE_API_KEY = config["youtube_key"]

# ── Catalog / Schema ────────────────────────────────────────
CATALOG = "bootcamp_students"          # your bootcamp catalog
YOUR_SCHEMA = "tiffani_ceresrain"    # replace with your name
# e.g. "tiffani_butterfly"

BRONZE_PATH = "bootcamp_students.tiffani_ceresrain_bronze"
SILVER_PATH = "bootcamp_students.tiffani_ceresrain_silver"
GOLD_PATH   = "bootcamp_students.tiffani_ceresrain_gold"

# ── Film List (start small, expand later) ───────────────────
FILM_LIST = [
   # 2005-2007 coverage
    {"title": "Batman Begins",        "release_date": "2005-06-15", "genre": "Action"},
    {"title": "Brokeback Mountain",   "release_date": "2005-12-09", "genre": "Drama"},
    {"title": "Casino Royale",        "release_date": "2006-11-17", "genre": "Action"},
    {"title": "The Departed",         "release_date": "2006-10-06", "genre": "Drama"},
    {"title": "No Country for Old Men", "release_date": "2007-11-09", "genre": "Thriller"},
    {"title": "There Will Be Blood",  "release_date": "2007-12-26", "genre": "Drama"},
    {"title": "Ratatouille",          "release_date": "2007-06-29", "genre": "Comedy"},
   
    # Pre Short-Form Era (2005–2014)
    {"title": "The Dark Knight",          "release_date": "2008-07-18", "genre": "Action"},
    {"title": "Inception",                "release_date": "2010-07-16", "genre": "Action"},
    {"title": "Avatar",                   "release_date": "2009-12-18", "genre": "Sci-Fi"},
    {"title": "The Social Network",       "release_date": "2010-10-01", "genre": "Drama"},
    {"title": "Interstellar",             "release_date": "2014-11-07", "genre": "Sci-Fi"},
    {"title": "Gone Girl",                "release_date": "2014-10-03", "genre": "Thriller"},
    {"title": "The Wolf of Wall Street",  "release_date": "2013-12-25", "genre": "Drama"},
    {"title": "Gravity",                  "release_date": "2013-10-04", "genre": "Sci-Fi"},
    {"title": "The Hangover",             "release_date": "2009-06-05", "genre": "Comedy"},
    {"title": "Bridesmaids",              "release_date": "2011-05-13", "genre": "Comedy"},
    {"title": "Paranormal Activity",      "release_date": "2009-10-16", "genre": "Horror"},
    {"title": "The Conjuring",            "release_date": "2013-07-19", "genre": "Horror"},

    # Transition Era (2015–2018)
    {"title": "Mad Max: Fury Road",       "release_date": "2015-05-15", "genre": "Action"},
    {"title": "The Revenant",             "release_date": "2015-12-25", "genre": "Drama"},
    {"title": "La La Land",               "release_date": "2016-12-09", "genre": "Drama"},
    {"title": "Get Out",                  "release_date": "2017-02-24", "genre": "Horror"},
    {"title": "It",                       "release_date": "2017-09-08", "genre": "Horror"},
    {"title": "Black Panther",            "release_date": "2018-02-16", "genre": "Action"},
    {"title": "Crazy Rich Asians",        "release_date": "2018-08-15", "genre": "Comedy"},
    {"title": "A Quiet Place",            "release_date": "2018-04-06", "genre": "Horror"},
    {"title": "Hereditary",               "release_date": "2018-06-08", "genre": "Horror"},
    {"title": "Bohemian Rhapsody",        "release_date": "2018-11-02", "genre": "Drama"},

    # Short-Form Era (2019+)
    {"title": "Joker",                    "release_date": "2019-10-04", "genre": "Drama"},
    {"title": "Parasite",                 "release_date": "2019-11-08", "genre": "Thriller"},
    {"title": "Tenet",                    "release_date": "2020-09-03", "genre": "Action"},
    {"title": "Dune",                     "release_date": "2021-10-22", "genre": "Sci-Fi"},
    {"title": "The Batman",               "release_date": "2022-03-04", "genre": "Action"},
    {"title": "Top Gun: Maverick",        "release_date": "2022-05-27", "genre": "Action"},
    {"title": "Everything Everywhere All at Once", "release_date": "2022-03-25", "genre": "Sci-Fi"},
    {"title": "Morbius",                  "release_date": "2022-04-01", "genre": "Action"},
    {"title": "Nope",                     "release_date": "2022-07-22", "genre": "Horror"},
    {"title": "The Menu",                 "release_date": "2022-11-18", "genre": "Thriller"},
    {"title": "Oppenheimer",              "release_date": "2023-07-21", "genre": "Drama"},
    {"title": "Barbie",                   "release_date": "2023-07-21", "genre": "Comedy"},
    {"title": "The Flash",                "release_date": "2023-06-16", "genre": "Action"},
    {"title": "Indiana Jones and the Dial of Destiny", "release_date": "2023-06-30", "genre": "Action"},
    {"title": "Five Nights at Freddy's", "release_date": "2023-10-27", "genre": "Horror"},
    {"title": "Poor Things",              "release_date": "2023-12-08", "genre": "Drama"},
    # 2024-2025 coverage
    {"title": "Dune: Part Two",       "release_date": "2024-03-01", "genre": "Sci-Fi"},
    {"title": "Inside Out 2",         "release_date": "2024-06-14", "genre": "Comedy"},
    {"title": "Deadpool & Wolverine", "release_date": "2024-07-26", "genre": "Action"},
    {"title": "Alien: Romulus",       "release_date": "2024-08-16", "genre": "Horror"},
    {"title": "Wicked",               "release_date": "2024-11-22", "genre": "Drama"},
]

# ── Era Logic ───────────────────────────────────────────────
def assign_era(year):
    if year <= 2014:
        return "Pre Short-Form (2005-2014)"
    else:
        return "Short-Form Era (2015-2025)"

print(f"Config loaded.")
print(f"Bronze: {BRONZE_PATH}")
print(f"Silver: {SILVER_PATH}")
print(f"Gold:   {GOLD_PATH}")
print(f"Films loaded: {len(FILM_LIST)}")
# Out:
# Config loaded.
# Bronze: bootcamp_students.tiffani_ceresrain_bronze
# Silver: bootcamp_students.tiffani_ceresrain_silver
# Gold:   bootcamp_students.tiffani_ceresrain_gold
# Films loaded: 50
